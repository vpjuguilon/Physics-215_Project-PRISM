# %%
from hapi import *
import numpy as np
import matplotlib.pyplot as plt

# Initialize HITRAN database
db_begin('data')

# Gases and HITRAN molecule numbers
gases = {
    'H2O': 1,
    'CO2': 2,
    'O3': 3,
    'N2O': 4,
    'CO': 5,
    'CH4': 6,
    'O2': 7,
    'NO': 8,
    'SO2': 9,
    'NO2': 10,
}

# Wavenumber range (400–2500 nm = 25000 to 4000 cm⁻¹)
nu_min = 4000
nu_max = 25000

# Fetch HITRAN data for each gas, using the most abundant isotope (isotope 1)
for gas, ID in gases.items():
    fetch(gas, ID, 1, nu_min, nu_max)  # fixed: use isotope 1
# Out:
# Using data
#
# CH4
#                      Lines parsed: 170395
# CO
#                      Lines parsed: 735
# CO2
#                      Lines parsed: 71206
# H2O
#                      Lines parsed: 226543
# N2O
#                      Lines parsed: 6064
# NO
#                      Lines parsed: 132274
# NO2
#                      Lines parsed: 58611
# O2
#                      Lines parsed: 1402
# O3
#                      Lines parsed: 38484
# SO2
#                      Lines parsed: 7249
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: H2O
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
# Header written to data/H2O.header
# END DOWNLOAD
#                      Lines parsed: 226543
# PROCESSED
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: CO2
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
# Header written to data/CO2.header
# END DOWNLOAD
#                      Lines parsed: 71206
# PROCESSED
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: O3
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
# Header written to data/O3.header
# END DOWNLOAD
#                      Lines parsed: 38484
# PROCESSED
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: N2O
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
#   65536 bytes written to data/N2O.data
# Header written to data/N2O.header
# END DOWNLOAD
#                      Lines parsed: 6064
# PROCESSED
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: CO
#   65536 bytes written to data/CO.data
#   65536 bytes written to data/CO.data
# Header written to data/CO.header
# END DOWNLOAD
#                      Lines parsed: 735
# PROCESSED
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: CH4
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
#   65536 bytes written to data/CH4.data
# ...
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
#   65536 bytes written to data/NO.data
# Header written to data/NO.header
# END DOWNLOAD
#                      Lines parsed: 132274
# PROCESSED
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: SO2
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
# Header written to data/SO2.header
# END DOWNLOAD
#                      Lines parsed: 7249
# PROCESSED
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: NO2
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
# Header written to data/NO2.header
# END DOWNLOAD
#                      Lines parsed: 58611
# PROCESSED

# %%
# Wavenumber grid
step = 1.0
nu_grid = np.arange(nu_min, nu_max, step)

path_length = 100 # centimeters
temp = 296 # kelvin
pressure = 1 # atm

# %%
import pandas as pd
# Simulate absorption spectrum

def spectral_sim(gas_concentrations):
    """
    gas_concentrations: dictionary of gas names and their mole fractions
    Example: {'H2O': 0.02, 'CO2': 0.0004}
             or {'CO2': 1.0} for pure CO2
    """  
    
    if not hasattr(spectral_sim, "initialized"):
        db_begin('data')

        gases = {
        'H2O': 1,
        'CO2': 2,
        'O3': 3,
        'N2O': 4,
        'CO': 5,
        'CH4': 6,
        'O2': 7,
        'NO': 8,
        'SO2': 9,
        'NO2': 10,
        }

        spectral_sim.initialized = True
    
    gases_to_simulate = list(gas_concentrations.keys())
    
    # Prepare environment dictionary
    environment_dict = {
        'T': temp,
        'p': pressure,
        'l': path_length
    }
    
    diluent_dict = {}
    
    total_conc = 0
    # Add each gas and its concentration
    for gas, conc in gas_concentrations.items():
        print(gas, conc)
        diluent_dict[gas] = conc
        total_conc += conc
    diluent_dict['air'] = 1.0 - total_conc
    
    
    
    # Call the absorptionCoefficient function
    nu, coeff = absorptionCoefficient_Voigt(
        SourceTables=gases_to_simulate,
        Diluent=diluent_dict,  # or {'air': 1.0} depending on what you want
        Environment=environment_dict,
        OmegaGrid=nu_grid
    )

    
    # Convert wavenumber to wavelength (nm)
    wavelength_nm = 1e7 / nu
    wavelength_nm = wavelength_nm[::-1]
    coeff = coeff[::-1]
        
    return coeff

#     # Plotting
#     plt.figure(figsize=(12, 5))
#     plt.plot(wavelength_nm, coeff)
#     plt.xlabel('Wavelength (nm)')
#     plt.ylabel('Absorption Coefficient (cm⁻¹)')
    
#     gases_label = ' + '.join(gases_to_simulate)
#     plt.title(f'Simulated Absorption Spectrum: {gases_label}')
#     plt.grid(True)
#     plt.xlim(400, 2500)
#     plt.tight_layout()
#     plt.show()
#     print(diluent_dict)
    
#     df = pd.DataFrame({
#         'Wavelength (nm)': wavelength_nm,
#         'Absorption Coefficient (cm-1)': coeff
#     })

    # Save to a CSV file
    #df.to_csv('absorption_spectrum.csv', index=False)

# %%
air_samples_df = pd.read_csv("concentration_label_2.csv", usecols=['CO2 (ppm)', 'NO2 (ppb)'])
air_samples_df = air_samples_df.rename(columns={'CO2 (ppm)': 'CO2', 'NO2 (ppb)': 'NO2'})

# %%
print(air_samples_df.head(10))
print(air_samples_df.info())
# Out:
#            CO2         NO2
# 0   999.264190  121.548216
# 1  1921.142890   34.187772
# 2  1571.190307   13.103813
# 3  1357.853575  189.782219
# 4   649.629825  193.129843
# 5   649.591233  161.698630
# 6   492.933779   60.992292
# 7  1785.881833   19.624656
# 8  1361.784019  136.878182
# 9  1532.916124   88.086483
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO2     30 non-null     float64
#  1   NO2     30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes
# None

# %%
import time

spectra_arr = []
first_start_time = time.time()

for index, row in air_samples_df.iterrows():
    print(index)
    start_time = time.time()
    spectra_arr.append(spectral_sim({'CO2': row[0]*1e-6, 'NO2': row[1]*1e-9}))#, 'CH4': row[2]*1e-9}))
    
    # Stop timer
    end_time = time.time()
    print(f"Total Elapsed time: {end_time - first_start_time:.4f} seconds")
    print("")
# Out:
# 0
# {'CO2': 0.00099926419015578, 'NO2': 1.2154821589509752e-07, 'air': 0.9990006142616283}
# 122.708042 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 124.1152 seconds
#
# 1
# {'CO2': 0.0019211428902558658, 'NO2': 3.418777232508958e-08, 'air': 0.9980788229219718}
# 131.682140 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 257.7415 seconds
#
# 2
# {'CO2': 0.001571190306898248, 'NO2': 1.3103813437757377e-08, 'air': 0.9984287965892883}
# 129.767060 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 389.4778 seconds
#
# 3
# {'CO2': 0.001357853574715259, 'NO2': 1.897822188969413e-07, 'air': 0.9986419566430659}
# 132.252956 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 523.6706 seconds
#
# 4
# {'CO2': 0.0006496298247078984, 'NO2': 1.9312984341160443e-07, 'air': 0.9993501770454487}
# 132.065350 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 657.6180 seconds
#
# 5
# {'CO2': 0.0006495912325379243, 'NO2': 1.616986298884806e-07, 'air': 0.9993502470688322}
# 131.101954 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 790.7079 seconds
#
# 6
# {'CO2': 0.0004929337794691192, 'NO2': 6.09922924577568e-08, 'air': 0.9995070052282384}
# 131.178376 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 923.7932 seconds
#
# 7
# {'CO2': 0.0017858818332398961, 'NO2': 1.9624655589876135e-08, 'air': 0.9982140985421045}
# 131.337882 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 1057.1819 seconds
#
# 8
# {'CO2': 0.001361784018789134, 'NO2': 1.3687818199978018e-07, 'air': 0.9986380791030288}
# 130.041386 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 1189.2145 seconds
#
# 9
# {'CO2': 0.0015329161244736727, 'NO2': 8.808648349854631e-08, 'air': 0.9984669957890429}
# 131.486984 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 1322.6756 seconds
#
# 10
# {'CO2': 0.0004329351908732839, 'NO2': 2.449544314547129e-08, 'air': 0.9995670403136836}
# 132.086612 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 1456.7339 seconds
#
# 11
# {'CO2': 0.0019518557634591908, 'NO2': 9.90858643312429e-08, 'air': 0.9980480451506765}
# 132.809001 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 1591.4412 seconds
#
# 12
# {'CO2': 0.0017319082252806746, 'NO2': 6.974265370932157e-09, 'air': 0.9982680848004539}
# 132.583493 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 1725.8942 seconds
#
# 13
# {'CO2': 0.0007397425770852418, 'NO2': 1.8187314837554853e-07, 'air': 0.9992600755497664}
# 130.770609 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 1858.5854 seconds
#
# 14
# {'CO2': 0.000690919947531361, 'NO2': 5.183011832184339e-08, 'air': 0.9993090282223503}
# 131.530483 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 1992.1202 seconds
#
# 15
# {'CO2': 0.000693447215765494, 'NO2': 1.32538204642361e-07, 'air': 0.9993064202460299}
# 131.280869 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 2125.3042 seconds
#
# 16
# {'CO2': 0.0008867875887352603, 'NO2': 6.241104411027325e-08, 'air': 0.9991131500002206}
# 134.294544 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 2261.5977 seconds
#
# 17
# {'CO2': 0.0012396102906115807, 'NO2': 1.0406159743344438e-07, 'air': 0.998760285647791}
# 130.751021 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 2394.3606 seconds
#
# 18
# {'CO2': 0.0010911120298273851, 'NO2': 1.093873848407216e-07, 'air': 0.9989087785827878}
# 126.285795 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 2522.4861 seconds
#
# 19
# {'CO2': 0.000865966624316867, 'NO2': 3.7052405659552865e-08, 'air': 0.9991339963232775}
# 129.742698 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 2654.2741 seconds
#
# 20
# {'CO2': 0.0013789646315558069, 'NO2': 1.939199670901353e-07, 'air': 0.9986208414484771}
# 125.826145 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 2781.9626 seconds
#
# 21
# {'CO2': 0.0006231901770432669, 'NO2': 1.550490513898868e-07, 'air': 0.9993766547739054}
# 129.939916 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 2913.8950 seconds
#
# 22
# {'CO2': 0.0008674314376563491, 'NO2': 1.8790583841868143e-07, 'air': 0.9991323806565052}
# 130.734740 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 3046.5608 seconds
#
# 23
# {'CO2': 0.0009861789492699067, 'NO2': 1.7897598735048702e-07, 'air': 0.9990136420747427}
# 129.743109 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 3178.1357 seconds
#
# 24
# {'CO2': 0.0011297119747472573, 'NO2': 1.1962020576433594e-07, 'air': 0.9988701684050469}
# 131.830542 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 3311.9057 seconds
#
# 25
# {'CO2': 0.0016562815382288217, 'NO2': 1.8438265958112103e-07, 'air': 0.9983435340791116}
# 131.642666 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 3445.5001 seconds
#
# 26
# {'CO2': 0.0007194780514533756, 'NO2': 1.7789651160178712e-08, 'air': 0.9992805041588955}
# 131.437450 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 3578.9652 seconds
#
# 27
# {'CO2': 0.0012227751014617786, 'NO2': 3.927697419758713e-08, 'air': 0.998777185621564}
# 129.947053 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 3710.8968 seconds
#
# 28
# {'CO2': 0.0013478633101792678, 'NO2': 9.140935053216562e-09, 'air': 0.9986521275488857}
# 131.478741 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 3844.2328 seconds
#
# 29
# {'CO2': 0.0004743206603519964, 'NO2': 6.513353311957655e-08, 'air': 0.9995256142061149}
# 127.512950 seconds elapsed for abscoef; nlines = 58611
# Total Elapsed time: 3973.8502 seconds

# %%
dataset_df = pd.DataFrame(spectra_arr, columns=(1e7/nu_grid)[::-1])
dataset_df.to_csv("spectra2.csv")

# %%
print(dataset_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Columns: 21000 entries, 400.0160006400256 to 2500.0
# dtypes: float64(21000)
# memory usage: 4.8 MB
# None

# %%
import time
from joblib import Parallel, delayed


spectra_arr = []
first_start_time = time.time()

rows_list = air_samples_df.to_dict(orient='records')
# Parallel processing using joblib
spectra_arr = Parallel(n_jobs=4)(delayed(spectral_sim)(row) for row in rows_list)

# Measure total elapsed time
end_time = time.time()
print(f"Total Elapsed time: {end_time - first_start_time:.4f} seconds")
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\vpjuguilon\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 436, in _process_worker
#     r = call_item()
#   File "C:\Users\vpjuguilon\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 288, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "C:\Users\vpjuguilon\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\vpjuguilon\anaconda3\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\vpjuguilon\anaconda3\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\vpjuguilon\AppData\Local\Temp\ipykernel_14196\3760443999.py", line 51, in spectral_sim
#   File "C:\Users\vpjuguilon\anaconda3\lib\site-packages\hapi\hapi.py", line 35640, in absorptionCoefficient_Voigt
#     return absorptionCoefficient_Generic(*args,**kwargs,
#   File "C:\Users\vpjuguilon\anaconda3\lib\site-packages\hapi\hapi.py", line 35551, in absorptionCoefficient_Generic
#     raise Exception('Diluent fraction must be in [0,1]')
# Exception: Diluent fraction must be in [0,1]
# """
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[24], line 10
#       8 rows_list = air_samples_df.to_dict(orient='records')
#       9 # Parallel processing using joblib
# ---> 10 spectra_arr = Parallel(n_jobs=4)(delayed(spectral_sim)(row) for row in rows_list)
#      12 # Measure total elapsed time
#      13 end_time = time.time()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1061, in Parallel.__call__(self, iterable)
#    1058     self._iterating = False
#    1060 with self._backend.retrieval_context():
# -> 1061     self.retrieve()
#    1062 # Make sure that we get a last message telling us we are done
#    1063 elapsed_time = time.time() - self._start_time
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:938, in Parallel.retrieve(self)
#     936 try:
#     937     if getattr(self._backend, 'supports_timeout', False):
# --> 938         self._output.extend(job.get(timeout=self.timeout))
#     939     else:
#     940         self._output.extend(job.get())
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# Exception: Diluent fraction must be in [0,1]
