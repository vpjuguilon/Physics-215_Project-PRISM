# %%
from hapi import *
import numpy as np
import matplotlib.pyplot as plt

# Initialize HITRAN database
db_begin('data')

# Gases and HITRAN molecule numbers
gases = {
    'H2O': 1,
    'CO2': 2,
    'O3': 3,
    'N2O': 4,
    'CO': 5,
    'CH4': 6,
    'O2': 7,
    'NO': 8,
    'SO2': 9,
    'NO2': 10,
}

# Wavenumber range (400–2500 nm = 25000 to 4000 cm⁻¹)
nu_min = 4000
nu_max = 25000

# Fetch HITRAN data for each gas, using the most abundant isotope (isotope 1)
for gas, ID in gases.items():
    fetch(gas, ID, 1, nu_min, nu_max)  # fixed: use isotope 1
# Out:
# Using data
#
# CH4
#                      Lines parsed: 170395
# CO
#                      Lines parsed: 735
# CO2
#                      Lines parsed: 71206
# H2O
#                      Lines parsed: 226543
# N2O
#                      Lines parsed: 6064
# NO
#                      Lines parsed: 132274
# NO2
#                      Lines parsed: 58611
# O2
#                      Lines parsed: 1402
# O3
#                      Lines parsed: 38484
# SO2
#                      Lines parsed: 7249
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: H2O
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
#   65536 bytes written to data/H2O.data
# ...

# %%
# Wavenumber grid
step = 1.0
nu_grid = np.arange(nu_min, nu_max, step)

path_length = 100 # centimeters
temp = 296 # kelvin
pressure = 1 # atm

# %%
import pandas as pd
# Simulate absorption spectrum

def spectral_sim(gas_concentrations):
    """
    gas_concentrations: dictionary of gas names and their mole fractions
    Example: {'H2O': 0.02, 'CO2': 0.0004}
             or {'CO2': 1.0} for pure CO2
    """  
    
    if not hasattr(spectral_sim, "initialized"):
        db_begin('data')

        gases = {
        'H2O': 1,
        'CO2': 2,
        'O3': 3,
        'N2O': 4,
        'CO': 5,
        'CH4': 6,
        'O2': 7,
        'NO': 8,
        'SO2': 9,
        'NO2': 10,
        }

        spectral_sim.initialized = True
    
    gases_to_simulate = list(gas_concentrations.keys())
    
    # Prepare environment dictionary
    environment_dict = {
        'T': temp,
        'p': pressure,
        'l': path_length
    }
    
    diluent_dict = {}
    
    total_conc = 0
    # Add each gas and its concentration
    for gas, conc in gas_concentrations.items():
        print(gas, conc)
        diluent_dict[gas] = conc
        total_conc += conc
    diluent_dict['air'] = 1.0 - total_conc
    
    
    
    # Call the absorptionCoefficient function
    nu, coeff = absorptionCoefficient_Voigt(
        SourceTables=gases_to_simulate,
        Diluent=diluent_dict,  # or {'air': 1.0} depending on what you want
        Environment=environment_dict,
        OmegaGrid=nu_grid
    )

    
    # Convert wavenumber to wavelength (nm)
    wavelength_nm = 1e7 / nu
    wavelength_nm = wavelength_nm[::-1]
    coeff = coeff[::-1]
        
    return coeff

#     # Plotting
#     plt.figure(figsize=(12, 5))
#     plt.plot(wavelength_nm, coeff)
#     plt.xlabel('Wavelength (nm)')
#     plt.ylabel('Absorption Coefficient (cm⁻¹)')
    
#     gases_label = ' + '.join(gases_to_simulate)
#     plt.title(f'Simulated Absorption Spectrum: {gases_label}')
#     plt.grid(True)
#     plt.xlim(400, 2500)
#     plt.tight_layout()
#     plt.show()
#     print(diluent_dict)
    
#     df = pd.DataFrame({
#         'Wavelength (nm)': wavelength_nm,
#         'Absorption Coefficient (cm-1)': coeff
#     })

    # Save to a CSV file
    #df.to_csv('absorption_spectrum.csv', index=False)

# %%
air_samples_df = pd.read_csv("concentration_label_3.csv")
print(air_samples_df.head(10))
print(air_samples_df.info())
# Out:
#              CO       CH4           N2O
# 0  3.807947e-06  0.000002  3.483556e-07
# 1  9.512072e-06  0.000003  3.341848e-07
# 2  7.346740e-06  0.000003  3.387643e-07
# 3  6.026719e-06  0.000002  3.409909e-07
# 4  1.644585e-06  0.000002  3.436821e-07
# 5  1.644346e-06  0.000002  3.535553e-07
# 6  6.750278e-07  0.000002  3.359902e-07
# 7  8.675144e-06  0.000003  3.454270e-07
# 8  6.051039e-06  0.000003  3.477724e-07
# 9  7.109919e-06  0.000002  3.313935e-07
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO      10 non-null     float64
#  1   CH4     10 non-null     float64
#  2   N2O     10 non-null     float64
# dtypes: float64(3)
# memory usage: 368.0 bytes
# None

# %%
# import time

# spectra_arr = []
# first_start_time = time.time()

# for index, row in air_samples_df.iterrows():
#     print(index)
#     start_time = time.time()
#     spectra_arr.append(spectral_sim({'CO2': row[0]*1e-6, 'NO2': row[1]*1e-9}))#, 'CH4': row[2]*1e-9}))
    
#     # Stop timer
#     end_time = time.time()
#     print(f"Total Elapsed time: {end_time - first_start_time:.4f} seconds")
#     print("")

# %%
# dataset_df = pd.DataFrame(spectra_arr, columns=(1e7/nu_grid)[::-1])
# dataset_df.to_csv("spectra2.csv")

# %%
# print(dataset_df.info())

# %%
import time
from joblib import Parallel, delayed


spectra_arr = []
first_start_time = time.time()

rows_list = air_samples_df.to_dict(orient='records')
# Parallel processing using joblib
spectra_arr = Parallel(n_jobs=10)(delayed(spectral_sim)(row) for row in rows_list)

# Measure total elapsed time
end_time = time.time()
print(f"Total Elapsed time: {end_time - first_start_time:.4f} seconds")
# Out:
# Total Elapsed time: 418.5769 seconds

# %%
dataset_df = pd.DataFrame(spectra_arr, columns=(1e7/nu_grid)[::-1])
dataset_df.to_csv("spectra3.csv")

# %%
print(len(spectra_arr))
plt.plot((1e7/nu_grid)[::-1], spectra_arr[2])
plt.show()
# Out:
# 10
