# %%
from hapi import *
import numpy as np
import matplotlib.pyplot as plt

# Initialize HITRAN database
db_begin('data')

# Gases and HITRAN molecule numbers
gases = {
    #'H2O': 1,
    #'CO2': 2,
    'O3': 3,
    #'N2O': 4,
    #'CO': 5,
    'CH4': 6,
    #'O2': 7,
    #'NO': 8,
    'SO2': 9,
    'NO2': 10,
    'C2H6': 27,
    'C2H4': 38
    
}

# Wavenumber range
nu_min = 900
nu_max = 1700

# Fetch HITRAN data for each gas, using the most abundant isotope (isotope 1)
for gas, ID in gases.items():
    fetch(gas, ID, 1, nu_min, nu_max)  # fixed: use isotope 1
# Out:
# Using data
#
# NO2
#                      Lines parsed: 49725
# O3
#                      Lines parsed: 22651
# SO2
#                      Lines parsed: 138167
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: O3
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
#   65536 bytes written to data/O3.data
# Header written to data/O3.header
# END DOWNLOAD
#                      Lines parsed: 70044
# PROCESSED
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: SO2
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
#   65536 bytes written to data/SO2.data
# Header written to data/SO2.header
# END DOWNLOAD
#                      Lines parsed: 189919
# PROCESSED
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: NO2
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
#   65536 bytes written to data/NO2.data
# Header written to data/NO2.header
# END DOWNLOAD
#                      Lines parsed: 54260
# PROCESSED

# %%
# Wavenumber grid
step = 1.0
nu_grid = np.arange(nu_min, nu_max, step)

path_length = 0.013 # centimeters
temp = 296 # kelvin
pressure = 1 # atm

# %%
import pandas as pd

def spectral_sim(gas_concentrations):
    """
    gas_concentrations: dictionary of gas names and their mole fractions
    Example: {'H2O': 0.02, 'CO2': 0.0004}
             or {'CO2': 1.0} for pure CO2
    Returns:
        wavelength_nm: array of wavelengths in nanometers (nm)
        trans: array of transmittance values
    """  
    
    if not hasattr(spectral_sim, "initialized"):
        db_begin('data')

        gases = {
            #'H2O': 1,
            #'CO2': 2,
            'O3': 3,
            #'N2O': 4,
            #'CO': 5,
            #'CH4': 6,
            #'O2': 7,
            #'NO': 8,
            'SO2': 9,
            'NO2': 10,
        }

        spectral_sim.initialized = True
    
    gases_to_simulate = [gas for gas, conc in gas_concentrations.items() if conc > 0]
    
    total_conc = sum(conc for conc in gas_concentrations.values() if conc > 0)
    
    environment_dict = {
        'T': temp,
        'p': pressure,
        'l': path_length,
        'VMR': {gas: conc for gas, conc in gas_concentrations.items() if conc > 0}
    }
    
    nu, coeff = absorptionCoefficient_Voigt(
        SourceTables=gases_to_simulate,
        Diluent={'air': max(0.0, 1.0 - total_conc)},
        Environment=environment_dict,
        OmegaGrid=nu_grid,
        HITRAN_units=False
    )

    # Compute transmittance
    nu, trans = transmittanceSpectrum(nu, coeff, Environment=environment_dict)

    # Convert wavenumber (cm⁻¹) to wavelength (nm)
    wavelength_nm = 1e7 / nu
    wavelength_nm = wavelength_nm[::-1]
    trans = 1 - trans[::-1]

    return trans

# %%
air_samples_df = pd.read_csv("NO2_label_single_test.csv")
print(air_samples_df.head(10))
print(air_samples_df.info())
# Out:
#             NO2
# 0  1.643221e-16
# 1  2.752327e-16
# 2  5.434811e-17
# 3  4.016962e-17
# 4  2.696797e-16
# 5  9.221747e-17
# 6  1.032797e-16
# 7  7.971277e-17
# 8  1.807292e-16
# 9  1.103898e-16
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NO2     16 non-null     float64
# dtypes: float64(1)
# memory usage: 256.0 bytes
# None

# %%
import time
from joblib import Parallel, delayed
from tqdm import tqdm
from tqdm_joblib import tqdm_joblib

spectra_arr = []
first_start_time = time.time()

rows_list = air_samples_df.to_dict(orient='records')

# Parallel processing using joblib
with tqdm_joblib(tqdm(desc="Processing rows", total=len(rows_list))):
    spectra_arr = Parallel(n_jobs=-1)(delayed(spectral_sim)(row) for row in rows_list)

# Measure total elapsed time
end_time = time.time()
print(f"Total Elapsed time: {end_time - first_start_time:.4f} seconds")
# Out:
# Processing rows:   0%|                                                                          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
# Total Elapsed time: 40.5288 seconds

# %%
dataset_df = pd.DataFrame(spectra_arr, columns=(1e7/nu_grid)[::-1])
dataset_df.to_csv("NO2_spectra_single_test.csv")

# %%
print(len(spectra_arr))
plt.plot((1e7/nu_grid)[::-1], spectra_arr[7])
plt.xlim(2500, 3300)
#plt.ylim(-85, -15)
plt.show()
# Out:
# 16

# %%
x = (1e7 / nu_grid)[::-1]
y1 = spectral_sim({'NO2': 0.3, 'SO2':0, 'O3':0})
y2 = spectral_sim({'NO2': 0.28, 'SO2':0, 'O3':0})
y3 = spectral_sim({'NO2': 0.26, 'SO2':0, 'O3':0})

print()

plt.plot(x, y1, label='y1')
plt.plot(x, y2, label='y2')
plt.plot(x, y3, label='y3')
plt.legend()
plt.show()


delta_A = y1 - y3
delta_B = y1 - y2
plt.plot(x, delta_A)
plt.plot(x, delta_B)
plt.title("Difference")
plt.show()
# Out:
# Using data
#
# NO2
#                      Lines parsed: 54260
# O3
#                      Lines parsed: 70044
# SO2
#                      Lines parsed: 189919
# {'air': 0.7}
# 9.126991 seconds elapsed for abscoef; nlines = 54260
# {'air': 0.72}
# 9.456697 seconds elapsed for abscoef; nlines = 54260
# {'air': 0.74}
# 9.112786 seconds elapsed for abscoef; nlines = 54260

# %%
x = (1e7 / nu_grid)[::-1]
y1 = spectral_sim({'NO2': 0.3, 'SO2':0.0, 'O3':0.0})
y2 = spectral_sim({'NO2': 0.0, 'SO2':0.3, 'O3':0.0})
y3 = spectral_sim({'NO2': 0.0, 'SO2':0.0, 'O3':0.3})

print()

plt.plot(x, y1, label='NO2')
plt.plot(x, y2, label='SO2')
plt.plot(x, y3, label='O3')
plt.legend()
plt.show()
# Out:
# {'air': 0.7}
# 9.432143 seconds elapsed for abscoef; nlines = 54260
# {'air': 0.7}
# 45.384277 seconds elapsed for abscoef; nlines = 189919
# {'air': 0.7}
# 13.708976 seconds elapsed for abscoef; nlines = 70044
